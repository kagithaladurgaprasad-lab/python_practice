# %%
a=50
print(a)
# Out:
# 50

# %%
b=a
print(b)
# Out:
# 50

# %%
name="ABC"
age="100"
city="vij"
print("NAME:",name)
print("AGE:",age)
print("CITY:",city)
#print(Name)
# Out:
# NAME: ABC
# AGE: 100
# CITY: vij

# %%
a=5
b=10
c=a
print(id(a))
print(id(b))
print(id(c))
# Out:
# 140718135358504
# 140718135358664
# 140718135358504

# %%
#assign same value to multiple variables
x=y=z=50
print(x)
print(y)
print(z)
# Out:
# 50
# 50
# 50

# %%
a=10
a
# Out:
# 10

# %%
#assign multiple values to multiple variables
a,b,c=5,20,30
print(a)
print(b)
print(c)
# Out:
# 5
# 20
# 30

# %%
#reassign variables
x=5
print(id(x))
x=x+5
print(id(x))
# Out:
# 140718135358504
# 140718135358664

# %%
#swapping variables
a=10
b=5
a,b=b,a
print(a)
print(b)
# Out:
# 5
# 10
