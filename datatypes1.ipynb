# %% [markdown]
# ## integer data type

# %%
a=5
print(a)
print(type(a))
c=0
print(type(c))
# Out:
# 5
# <class 'int'>
# <class 'int'>

# %% [markdown]
# ## float data type

# %%
b=40.5
print("value:",b)
print(type(b))
d=-10.6
print(type(d))
# Out:
# value: 40.5
# <class 'float'>
# <class 'float'>

# %% [markdown]
# ## complex data type

# %%
e=1+3j
print(e)
print(type(e))
# Out:
# (1+3j)
# <class 'complex'>

# %% [markdown]
# ## sequence datatypes

# %% [markdown]
# ## string datatype

# %%
a='hello'
print(a)
print(type(a))
# Out:
# hello
# <class 'str'>

# %%
b="hello"
print(b)
# Out:
# hello

# %%
c="hello @ hi"
print(c)
print(type(c))
# Out:
# hello @ hi
# <class 'str'>

# %%
d="hello\nhi\teveryone"
print(d)
print(type(d))
# Out:
# hello
# hi	everyone
# <class 'str'>

# %%
a='''hello'''
b=""" every one"""
print(a)
print(b)
# Out:
# hello
#  every one

# %%
#indexing sclinging
a="hello"
print("positive indexing")
print(a[0])
print(a[1])
print(a[2])
print(a[3])
print(a[4])
print("negative indexing")
print(a[-1])
print(a[-2])
print(a[-3])
print(a[-4])
print(a[-5])
print("sclicing positive indexing \n ")
print(a[0:5])
print(a[1:4])
print(a[:5])
print(a[1:])
print("sclicing negative indexing \n ")
b="HEADPHONES"
print(b[-9:-4])
print(b[-6:-1])
print(b[:])
print(b[-10:])
print(b[:-7])
# Out:
# positive indexing
# h
# e
# l
# l
# o
# negative indexing
# o
# l
# l
# e
# h
# sclicing positive indexing
#
# hello
# ell
# hello
# ello
# sclicing negative indexing
#
# EADPH
# PHONE
# HEADPHONES
# HEADPHONES
# HEA

# %%
b="HEADPHONES"
print(b[0:10:2])
print(b[0:11:3])
print(b[-10:-1:2])
print(b[::-1])
# Out:
# HAPOE
# HDOS
# HAPOE
# SENOHPDAEH

# %%
a="hi"
del a
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 3
#       1 a="hi"
#       2 del a
# ----> 3 print(a)
#
# NameError: name 'a' is not defined

# %%
d="hello "
d1="man"
print(d+d1)
# Out:
# hello man

# %%
c="hello"
print(c*3)
# Out:
# hellohellohello

# %%
d="12"
d1="23"
print(d+d1)
# Out:
# 1223

# %%
a="hello"
print(a)
b='what\'s gooing'
print(b)
# Out:
# hello
# what's gooing
