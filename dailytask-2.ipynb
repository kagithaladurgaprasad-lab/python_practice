# %% [markdown]
# ## LIST METHODS

# %%
#append() Create a list of city names. Add a new city "Delhi" using append() and print the updated list.
city=['vij','hyd']
city.append('delhi')
print(city)
# Out:
# ['vij', 'hyd', 'delhi']

# %%
#extend()
# You have a list [1, 2, 3]. Extend it with another list [4, 5, 6] using extend() and print the result.

list =[1, 2, 3]
a=[4,5,6]
list.extend(a)
print(list)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
#insert()
# Insert the number 99 at index 1 in the list [10, 20, 30]. Use insert() and print the new list.

list =[10, 20, 30]
list.insert(1,99)
print(list)
# Out:
# [10, 99, 20, 30]

# %%
#remove() #Remove the element "apple" from the list ["apple", "banana", "cherry"] using remove().
list= ["apple", "banana", "cherry"]
list.remove('apple')
print(list)
# Out:
# ['banana', 'cherry']

# %%
#pop()
# Use pop() to remove the last element from the list [100, 200, 300, 400]. Print the removed value and updated list.

list =[100, 200, 300, 400]
a=list.pop()
print(a)
print(list)
# Out:
# 400
# [100, 200, 300]

# %%
#index()
# Given the list ["dog", "cat", "parrot", "cat"], find the index of the first occurrence of "cat" using index().
list =["dog", "cat", "parrot", "cat"]
a=list.index("cat")
print(a)
# Out:
# 1

# %%
#count()
# Count how many times the number 7 appears in the list [7, 3, 7, 1, 7, 9]
list= [7, 3, 7, 1, 7, 9]
b=list.count(7)
print(b)
# Out:
# 3

# %%
#sort()
#Sort the list [5, 2, 9, 1, 7] in ascending order using sort() and print the result.
list =[5, 2, 9, 1, 7] 
list.sort()
print(list)
# Out:
# [1, 2, 5, 7, 9]

# %%
#reverse()
#Reverse the order of elements in the list [1, 2, 3, 4, 5] using reverse().
list= [1, 2, 3, 4, 5]
list.reverse()
print(list)
# Out:
# [5, 4, 3, 2, 1]

# %%
#copy()
#Copy the list ["red", "green", "blue"] to a new list using copy(). Modify the original list and show that the copied list remains unchanged.
list =["red", "green", "blue"] 
a=list.copy()
print(list)
list.append("black")
print(list)
print(a)
# Out:
# ['red', 'green', 'blue']
# ['red', 'green', 'blue', 'black']
# ['red', 'green', 'blue']

# %%
#clear()
#Remove all elements from the list [10, 20, 30] using clear(). Print the list after clearing.

list =[10, 20, 30]
list.clear()
print(list)
# Out:
# []

# %% [markdown]
# ##  Tuple Questions

# %%
#Tuple Count
#Given the tuple colors = ('red', 'blue', 'green', 'red', 'yellow', 'red'), count how many times 'red' appears.
colors = ('red', 'blue', 'green', 'red', 'yellow', 'red')
a=colors.count("red")
print(a)
# Out:
# 3

# %%
#Tuple Index
#Find the index of 'green' in the tuple colors = ('red', 'blue', 'green', 'yellow)
colors = ('red', 'blue', 'green', 'yellow')
a=colors.index('green')
print(a)
# Out:
# 2

# %% [markdown]
# ##  Set Questions

# %%
#Set Add
#Add 'cherry' to the set: fruits = {'apple', 'banana'}
fruits = {'apple', 'banana'}
fruits.add('cherry')
print(fruits)
# Out:
# {'banana', 'cherry', 'apple'}

# %%
#Set Update
#Add elements from another set {'orange', 'grape'} to fruits = {'apple'} using update().
fruits={'apple'}
fruits.update({'orange', 'grape'})

print(fruits)
# Out:
# {'grape', 'apple', 'orange'}

# %%
#Set Discard
#Discard 'banana' from fruits = {'apple', 'banana', 'cherry'}
fruits = {'apple', 'banana', 'cherry'}
fruits.discard('banana')
print(fruits)
# Out:
# {'cherry', 'apple'}

# %%
#Set Remove
#Remove 'apple' using remove() from fruits = {'apple', 'grape'}.
fruits = {'apple', 'grape'}
fruits.remove('apple')
print(fruits)
# Out:
# {'grape'}

# %%
#Set Pop
#Pop any element from colors = {'red', 'green', 'blue'} and store it in a variable.
colors = {'red', 'green', 'blue'} 
a=colors.pop()
print(a)
# Out:
# green

# %%
#Set Clear
#Clear all elements from numbers = {1, 2, 3, 4}.
numbers = {1, 2, 3, 4}
numbers.clear()
print(numbers)
# Out:
# set()

# %%
#Set Copy
#Make a copy of the set data = {1, 2, 3} and store it in a new variable.
data = {1, 2, 3}
b=data.copy()
print(b)
print(data)
# Out:
# {1, 2, 3}
# {1, 2, 3}

# %%
#Set Difference
#Find the difference between set1 = {1, 2, 3, 4} and set2 = {3, 4, 5, 6}.

set1 = {1, 2, 3, 4}
set2 = {3, 4, 5, 6}
b=set1.difference(set2)
c=set1-set2
print(b)
print(c)
# Out:
# {1, 2}
# {1, 2}

# %%
#Set Union
#Find the union of a = {'x', 'y'} and b = {'y', 'z'}.

a = {'x', 'y'}
b = {'y', 'z'}
print(a.union(b))
print(a|b)
# Out:
# {'z', 'x', 'y'}
# {'z', 'x', 'y'}

# %%
#Set Intersection
#Find common elements in set1 = {10, 20, 30} and set2 = {20, 40, 60}.
set1 = {10, 20, 30}
set2 = {20, 40, 60}
print(set1.intersection(set2))
print(set1 & set2)
# Out:
# {20}
# {20}

# %%
#Set issubset
#Check if {1, 2} is a subset of {1, 2, 3, 4}
a={1, 2, 3, 4}
b={1,2}
print(b.issubset(a))
# Out:
# False

# %%
#Set issuperset
#Check if {1, 2, 3} is a superset of {2, 3}.
a={1, 2, 3}
b= {2, 3}
print(a.issuperset(b))
# Out:
# True

# %%
#Set symmetric_difference
#Find elements not common in a = {1, 2, 3} and b = {3, 4, 5}.
a = {1, 2, 3} 
b = {3, 4, 5}
print(a.symmetric_difference(b))
# Out:
# {1, 2, 4, 5}

# %% [markdown]
# ##  Dictionary Questions

# %%
#Dictionary Keys
#Extract all keys froms tudent = {'name': 'John', 'age': 21}.
student = {'name': 'John', 'age': 21}
print(student.keys())
# Out:
# dict_keys(['name', 'age'])

# %%
#Dictionary Values
#Get all values from employee = {'id': 101, 'name': 'Alice', 'salary': 50000}.
employee = {'id': 101, 'name': 'Alice', 'salary': 50000}
print(student.values())
# Out:
# dict_values(['John', 21])

# %%
#Dictionary Items
#Get all key-value pairs from the above dictionary.
student = {'name': 'John', 'age': 21}
print(student.items())
# Out:
# dict_items([('name', 'John'), ('age', 21)])

# %%
#Dictionary Get
#Safely get the value for the key 'grade' in marks = {'math': 90, 'science': 85}.
marks = {'math': 90, 'science': 85}
print(student.get("grade","not found"))
# Out:
# not found

# %%
#Dictionary Update
#Update the value of 'salary' to 60000 in employee = {'name': 'Alice', 'salary': 50000}.
employee = {'name': 'Alice', 'salary': 50000}
employee.update({'salary':60000})
print(employee)
# Out:
# {'name': 'Alice', 'salary': 60000}

# %%
#Dictionary Pop
#Remove the key 'age' from person = {'name': 'Ravi', 'age': 30, 'city': 'Delhi'} using pop().
person = {'name': 'Ravi', 'age': 30, 'city': 'Delhi'} 
person.pop('age')
print(person)
# Out:
# {'name': 'Ravi', 'city': 'Delhi'}

# %%
#Dictionary Popitem
#Remove the last inserted item from data = {'a': 1, 'b': 2, 'c': 3} using popitem().
data = {'a': 1, 'b': 2, 'c': 3}
b=data.popitem()
print(b)
# Out:
# ('c', 3)

# %%
#Dictionary Clear
#Clear all contents from info = {'x': 100, 'y': 200}
info = {'x': 100, 'y': 200}
info.clear()
print(info)
# Out:
# {}

# %%
#Dictionary Copy
#Create a copy of config = {'theme': 'dark', 'lang': 'EN'}.
config = {'theme': 'dark', 'lang': 'EN'}
b=config.copy()
print(b)
# Out:
# {'theme': 'dark', 'lang': 'EN'}

# %%
#Dictionary Setdefault
#Set default value 'Not Found' for key 'country' in profile = {'name': 'Sam'}.
profile = {'name': 'Sam'}
print(profile.setdefault('country','not found'))
print(profile)
# Out:
# not found
# {'name': 'Sam', 'country': 'not found'}

# %%
#Dictionary Fromkeys
#Create a dictionary using fromkeys() with keys ['a', 'b', 'c'] and default value 0.
a=['a','b','c']
a1=dict.fromkeys(a,0)
print(a1)
# Out:
# {'a': 0, 'b': 0, 'c': 0}

# %% [markdown]
# ##  Slicing and Indexing Questions

# %%
#String Slicing
#Slice the first 4 characters from "DataScience".

s="DataScience"
print(s[0:4])
# Out:
# Data

# %%
#List Slicing
#Given nums = [10, 20, 30, 40, 50], slice elements from index 1 to 3.
nums = [10, 20, 30, 40, 50]
print(nums[1:3])
# Out:
# [20, 30]

# %%
#Tuple Slicing
#Get a slice from the tuple days = ('Mon', 'Tue', 'Wed', 'Thu', 'Fri') from index 2 onward.
days = ('Mon', 'Tue', 'Wed', 'Thu', 'Fri')
print(days[2:])
# Out:
# ('Wed', 'Thu', 'Fri')

# %%
#Negative Indexing
#Access the last character of text = "Python" using negative indexing.
text = "Python"
print(text[-1])
# Out:
# n

# %%
#Indexing in Tuple
#Access the element at index 3 in coordinates = (5, 10, 15, 20, 25).
coordinates = (5, 10, 15, 20, 25)
print(coordinates[3])
# Out:
# 20

# %%
#List Negative Indexing
#Get the second last element from nums = [1, 2, 3, 4, 5]
nums = [1, 2, 3, 4, 5]
print(nums[-2])
# Out:
# 4

# %% [markdown]
# ##  Updating Values

# %%
#Update Tuple via Reassignment
#Given t = (1, 2, 3), change it to (1, 2, 4) by creating a new tuple.
t = (1, 2, 3)
t1 = list(t)
t1[2]=4
t2=tuple(t1)
print(t2)
# Out:
# (1, 2, 4)

# %%
#Update List Element
#Change the second element to 99 in nums = [10, 20, 30].
nums = [10, 20, 30]
nums[1]=99
print(nums)
# Out:
# [10, 99, 30]

# %%
#Update Dictionary Value
#Update the value of 'status' to 'active' in user = {'name': 'Tom', 'status': 'inactive'}.
user = {'name': 'Tom', 'status': 'inactive'}
user['status']="active"
print(user)
# Out:
# {'name': 'Tom', 'status': 'active'}

# %% [markdown]
# ##  Key & Value Extraction Questions

# %%
#Extract Key
#Get the key 'city' from address = {'city': 'Mumbai', 'pin': 400001}.
address = {'city': 'Mumbai', 'pin': 400001}
a=list(address.keys())
b=a[0]
print(b)
# Out:
# city

# %%
#Extract Value
#Get the value associated with the key 'pin' from the above dictionary.
a=list(address.values())
b=a[1]
print(b)
# Out:
# 400001

# %% [markdown]
# ##  String Formatting: format() and f-strings

# %%
#Basic format()
#Use .format() to print: "Hello, my name is Alice and I am 25 years old."
name="Alice"
age=25
print("Hello, my namer is {} and i am {} years old".format(name,age))
# Out:
# Hello, my namer is Alice and i am 25 years old

# %%
#Multiple format()
#Print a message using placeholders: "{} scored {} out of {}" with values: "John", 85, 100.

print("{0} scored {1} out of {2}".format("jnon",85,100))
# Out:
# jnon scored 85 out of 100

# %%
## f-string Basic
#Use f-strings to print: "Hi, I’m Riya and my score is 92" using variables name = "Riya", score = 92.
name = "Riya"
score = 92
print(f"Hi,i'm {name} and my score is {score}")
# Out:
# Hi,i'm Riya and my score is 92

# %%
#f-string with expressions
#Given a = 5, b = 10, print "Sum is 15" using f-string with expression inside.
a=5
b=10
print(f"sum is {a+b}")
# Out:
# sum is 15

# %% [markdown]
# ## Set Methods

# %%
#add()
#Create a set of fruits: {"apple", "banana"}.
#Add a new fruit "mango" using add() and print the updated set.
fruits= {"apple", "banana"}
fruits.add("mango")
print(fruits)
# Out:
# {'apple', 'banana', 'mango'}

# %%
#update()
#You have a set {1, 2, 3}.
 #Update it with another set {4, 5, 6} using update() and print the result.
se={1,2,3}
set2={4,5,6}
se.update(set2)
print(se)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
#remove()
#Remove the element 50 from the set {10, 20, 30, 40, 50} using **remove()`.
# Print the updated set.
s={10, 20, 30, 40, 50}
s.remove(50)
print(s)
# Out:
# {20, 40, 10, 30}

# %%
#discard()
#Discard the value 100 from the set {50, 75, 100, 125} using discard().
# Print the final set and note that no error occurs if the element doesn’t exist.
s={50, 75, 100, 125}
s.discard(100)
print(s)
# Out:
# {50, 75, 125}

# %%
#Use pop() on the set {200, 300, 400, 500}.
# Print the removed value and the updated set.
 #(Explain that pop removes a random element.)
s= {200, 300, 400, 500}
print(s.pop())
print(s)
# Out:
# 200
# {500, 400, 300}

# %%
#clear()
#Remove all elements from the set {9, 8, 7} using clear().
 #Print the set after clearing.
se= {9, 8, 7}
se.clear()
print(se)
# Out:
# set()

# %%
#copy()
#Copy the set {1, 2, 3} using copy().
 #Modify the original set and show that the copied set does not change.
se= {1, 2, 3}
b=se.copy()
print(b)
se.add(4)
print(se)
# Out:
# {1, 2, 3}
# {1, 2, 3, 4}

# %%
#Given:
#A = {1, 2}
#B = {2, 3}

#Use union() to combine both sets and print the result.

A = {1, 2}
B = {2, 3}
print(A.union(B))
# Out:
# {1, 2, 3}

# %%
#intersection()
#Find the intersection of sets {4, 6, 8, 10} and {6, 7, 8} using intersection().
sets ={4, 6, 8, 10}
se={6, 7, 8}
print(sets.intersection(se))
# Out:
# {8, 6}

# %%
#difference()
#Given:
#A = {10, 20, 30}
#B = {20, 40}

#Find A.difference(B) and print the result.
A = {10, 20, 30}
B = {20, 40}
print(A.difference(B))
# Out:
# {10, 30}

# %%
#symmetric_difference()
#Given two sets {1, 2, 3} and {3, 4, 5}, find the symmetric difference using symmetric_difference().
sets= {1, 2, 3}
se= {3, 4, 5}
print(sets.symmetric_difference(se))
# Out:
# {1, 2, 4, 5}

# %%
#issubset()
#Check whether the set {2, 3} is a subset of {1, 2, 3, 4} using issubset().
s ={2, 3}
s1={1, 2, 3, 4} 
print(s.issubset(s1))
# Out:
# True

# %%
#issuperset()
#Use issuperset() to check if {10, 20, 30, 40} is a superset of {20, 30}.
a={10, 20, 30, 40}
b={20, 30}
print(a.issuperset(b))
# Out:
# True

# %%
#isdisjoint()
#Check if the sets {1, 3, 5} and {2, 4, 6} are disjoint using isdisjoint().
a= {1, 3, 5}
b={2, 4, 6}
print(a.isdisjoint(b))
# Out:
# True

# %%
#frozenset()
#Convert the list [1, 2, 3, 4, 5] into a frozenset.
 #Try adding a new value and explain why it fails.
li=[1, 2, 3, 4, 5]
b=frozenset(li)
b.append(2)
print(b)


#because frozen doesn't contain the append method means list is forcefully set to not to be modified with frozen
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 6
#       4 li=[1, 2, 3, 4, 5]
#       5 b=frozenset(li)
# ----> 6 b.append(2)
#       7 print(b)
#
# AttributeError: 'frozenset' object has no attribute 'append'

# %%
#intersection_update()
#Given:
#A = {1, 2, 3, 4}
#B = {3, 4, 5}

#Apply intersection_update() on A with B and print the updated A.

A = {1, 2, 3, 4}
B = {3, 4, 5}
A.intersection_update(B)
print(A)
# Out:
# {3, 4}

# %%
#difference_update()
#Given:
#A = {10, 20, 30, 40}
#B = {30, 40}

#Use difference_update() to remove common elements from A.
 #Print the updated A.
A = {10, 20, 30, 40}
B = {30, 40}
A.difference_update(B)
print(A)
# Out:
# {20, 10}

# %%
#symmetric_difference_update()
#Given:
#A = {1, 2, 3}
#B = {3, 4}

#Use symmetric_difference_update() on A and print the updated A.
A = {1, 2, 3}
B = {3, 4}
A.symmetric_difference_update(B)
print(A)
# Out:
# {1, 2, 4}

# %%
#Removing Multiple Items Using discard()
#Given:
#A = {5, 10, 15, 20, 25}

#Remove 10, 20, and 30 using discard() one by one.
# Print the final set.

A = {5, 10, 15, 20, 25}
A.discard(10)
A.discard(20)
A.discard(30)
print(A)
# Out:
# {5, 25, 15}

# %%
#Unique Values Using a Set
#Given the list [1, 1, 2, 3, 3, 4, 5], convert it into a set to keep only unique values.
#Print the result and explain how sets remove duplicates.
li= [1, 1, 2, 3, 3, 4, 5]
a=set(li)
print(a)


### sets takes unique values , it doesn't allow duplicates , it consider repeated elements as one element
# Out:
# {1, 2, 3, 4, 5}
