# %% [markdown]
# ## File handling

# %%
new_file=open('file.txt','r') #opens existing file for reading
if new_file:
    print("File opened")
# Out:
# File opened

# %%
new_file2=open(r"C:\Users\admin\OneDrive\Documents\innomatics\daily tasks\other_file.txt",'r') #opens existing file for reading
if new_file2:
    print("File opened")
# Out:
# File opened

# %%
new_file=open('file.txt','r') #opens existing file for reading
if new_file:
    print("File opened")
# Out:
# File opened

# %%
with open('file.txt','w')as file:
    file.write("Hello world")

# %%
#overwrite new content with old content


with open('file.txt','w')as file:
    file.write("python is very easy")

# %%
file.close()

# %%
with open ('file.txt','r')as f:
    content=f.read()  #Read entire file content 
    print(content)
# Out:
# python is very easy

# %%
file.close()

# %%
with open(r"C:\Users\admin\OneDrive\Documents\innomatics\daily tasks\other_file.txt",'w') as other:
    other.write("python is simple language")

# %%
other.close()

# %%
file=open('file.txt','a') #a= append new text
file.write(". it is fatest growing language")
file.close()

# %%
with open ('file.txt','r')as f:
    content=f.read(11) 
    print(content)
# Out:
# python is v

# %%
file.close()

# %%
file= open('file.txt','a')
file.write("\nDEveloped by gudio van rossum")
file.close()

# %%
file=open('file.txt','r')
content1=file.readline()
print(content1)
content2=file.readline()
print(content2)
file.close()
# Out:
# python is very easy. it is fatest growing language
#
# DEveloped by gudio van rossum

# %%
file=open('file.txt','r')
content=file.readlines()
print(content)
file.close()
# Out:
# ['python is very easy. it is fatest growing language\n', 'DEveloped by gudio van rossum']

# %%
#read()---->read the content
#read(n)--->reads the n characters
#readline()-->reads one line at a time
#readlines()--->reads all lines into a list

# %%
#create  A NEW FILE
file=open("python_new_file.txt","x")
file.write("python is very easy\n supports many applications")
file.close()

# %%
with open ('python_new_file.txt','r')as f:
    content=f.read() 
    print(content)
# Out:
# python is very easy
#  supports many applications

# %%
with open('dp.jpg','rb')as file:
    data=file.read()
    print(f"File size:{len(data)}bytes")
# Out:
# File size:55768bytes
