# %% [markdown]
# ### 📘 Probability — Revision Task Set
#
# # ✅ Task 1: Identify the Probability Components

# %% [markdown]
# #A die is rolled once.
# #1.Identify:
#
# #Random experiment:-Rolling a dice is a random experiment.action where the outcome is not certain .
# #Trail          :-we can say performing an experiment 0 to n times is called Trail,
# #Sample space  :-{1,2,3,4,5,6} all possiable outcomes
# #Event:Getting an even number:-{2,4,6}/total no.of possibilities

# %% [markdown]
# 2.Write the probability of the event.
#
# p(event)=outcome of event /total no.of outcomes

# %% [markdown]
# ✅ Task 2: Verify Probability Axioms
# Given probabilities of three events:
# P(A) = 0.3
#
#
# P(B) = 0.5
#
#
# P(C) = 0.2
#
#
# Check whether these values satisfy probability axioms.
#
#
# What is P(Sample Space)?
#
#
# What is the probability of an impossible event?

# %% [markdown]
# P(A) = 0.3
# P(B) = 0.5
# P(C) = 0.2
#
# 1)p(E)>0
# i.e ==>p(A),p(B),p(C)>0
# 2)p(s)={0.3,0.2,0.5}
# 3)p(impossible)=0

# %%
#think:-sum of all possible events is 1 ,because we consider possible event is 1

# %% [markdown]
# # 🔹 II. Independent Events, Conditional & Bayes Probability
# # ✅ Task 3: Independent or Dependent?
# # Classify the following event pairs as Independent or Dependent (with reason):

# %% [markdown]
# 1.tossing a coin twice
# ans.The result of the first toss does not affect the second toss.
#
# 2.Drawing two cards with replacement
# ans) if we take one card and replace it the posible outcome will be same that is 52 ,so it is independent event
#
# 3.Drawing two cards without replacement
# ans) if take one card and doesn't replace it the possible outcome is 51 so , it is independent
#
# 4.Selecting a student and their exam result
# p(A)=pass
# p(b)=fail
# the posible out comes is in pass or fail
# p(A)=0.5
# p(B)=0.5
# that is 50% of chances

# %% [markdown]
# If events are independent:
#
# Knowing event A happened gives you zero new information about event B.
#
# If events are dependent:
#
# Knowing event A happened changes your belief about event B.

# %%
✅ Task 4: Conditional & Bayes Thinking
In a company:
60% employees are Engineers
40% are Analysts
70% of Engineers know Python
30% of Analysts know Python
Answer:
What is the probability that a randomly selected employee knows Python
If an employee knows Python, are they more likely to be an Engineer or Analyst?

# %% [markdown]
# P(Python)=P(Python∣E)P(E)+P(Python∣A)P(A)
# P(Python)=(0.7×0.6)+(0.3×0.4)
# =0.42+0.12
# =0.54
# p(python)=0.54

# %%
#If an employee knows Python, are they more likely to be an Engineer or Analyst?
p_ep=(0.7*0.6)/0.54=0.78
p_ap=(0.3*0.4)/0.54=0.22

# %%
🔹 III. Marginal, Joint Probability & Contingency Tables
✅ Task 5: Contingency Table Interpretation
Pass
Fail
Total
Male
30
10
40
Female
50
10
60
Total
80
20
100
Find:
Joint Probability: P(Female ∩ Pass)
Marginal Probability: P(Pass)
Conditional Probability: P(Pass | Female)
👉 Challenge:
 Explain the difference between joint and conditional probability using this table.

# %%
#1.Joint probability means both events happen together.
P(Female ∩ Pass)=50/100=50%

#2.Marginal probability looks at total of one event only.
p_pass=80/100=0.8

#3.Probability of passing given that the student is female.
P(Pass | Female)=50/60=0.833

Joint probability = “Out of everyone, how many are female AND pass?”

Conditional probability = “Out of females only, how many pass?”

# %%
✅ Task 6: Reason Without Calculation
Using the table above, answer True or False with reason:
Passing and gender are independent events.
Probability of passing is higher for females.
Marginal probability ignores conditions.
👉 Think:
 How would independence reflect in the contingency table values?


1.P(Pass)=80/100=0.8
P(Pass∣Female)=50/60=0.833
Since 0.833 ≠ 0.8, they are not equal.

❌ False — Passing and gender are NOT independent.

Gender affects the probability of passing.
