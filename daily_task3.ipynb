# %% [markdown]
# ##  1. ARITHMETIC OPERATORS with Mixed operators

# %%
#Q1. John has 6 apples and 7 bananas. How many fruits does John have?
apples=6
bananas=7
print("john has:",apples+bananas)
# Out:
# john has: 13

# %%
#Q2. Emma read 15 pages yesterday and 10 pages today. Did she read more than 20 pages in total? 
ye=15
tod=10
tota=ye+tod
total=20
print("she read more than 20 pages ?" , tota>=total)
# Out:
# she read more than 20 pages ? True

# %%
# Q3. Mike had 30 candies an d gave 12 to his friend. How many does he have now? 
mike=30
friend=12
print("the candies does mike have" ,mike-friend)
# Out:
# the candies does mike have 18

# %%
# Q4. Sarah bought 5 pens at $3 each. How much did she spend?
sara=5
print("sara spend :",sara*3)
# Out:
# sara spend : 15

# %%
# Q5. There are 45 cookies equally divided among 5 kids. How many does each get? 
total=45
kids=5
print("each kid get:",total//kids)
# Out:
# each kid get: 9

# %%
# Q6. A chocolate costs $2. You have $9. Can you buy 5 chocolates?
cho=2
you_have=9
print("can i buy 5 chocolates?:",cho*5==9)
# Out:
# can i buy 5 chocolates?: False

# %%
#Q7. Peter has 5 books, each weighing 1.2 kg. Is the total weight more than 6 kg?
peter=5
wei=1.2
print("is total weight more than 6kg:",peter*1.2==6)
# Out:
# is total weight more than 6kg: True

# %%
#Q8. A movie ticket costs $12. Can you buy 4 with $50?
ticket=12
print("can i buy 4 with 50:",50//4==12)
# Out:
# can i buy 4 with 50: True

# %%
#Q9. Is the difference between 100 and 37 greater than 60?
print(100-37>60)
# Out:
# True

# %%
#Q10. Does dividing 81 by 9 result in a number greater than 8?
print(81//9>8)
# Out:
# True

# %%
#Q11. Are 5 multipled by 6 and 30 equal?
print(5*6==30)
# Out:
# True

# %%
#Q12. A basket holds 18 apples. If you eat 6, do you have fewer than 15 left?
apples=18
eat=6
print("do i have fewer than 15?:",apples-eat<15)
# Out:
# do i have fewer than 15?: True

# %%
#Q13. Sam travels 120 km in 2 hours. Is his speed 60 km/hr?
print("Is his speed 60 km/hr:",120/2==60)
# Out:
# Is his speed 60 km/hr: True

# %%
#Q14. Is 7 + 3 * 2 equal to 20?
print(7+3*2==20)
# Out:
# False

# %%
#Q15. Jane bought 2 pens and 3 pencils. If a pen is $2 and pencil $1, did she spend $9?
print("did she spend $9:",2*2+3*1==9)
# Out:
# did she spend $9: False

# %%
#Q16. You have 3 boxes, each holding 12 balls. Are total balls more than 35?
print(3*12>35)
# Out:
# True

# %%
#Q17. Does subtracting 20 from 50 give 30?
print(50-20==30)
# Out:
# True

# %%
#Q18. Are 10 + 15 and 5 * 5 equal?
print(10+15==5*5)
# Out:
# True

# %%
#Q19. If a packet has 48 candies, can 6 kids get more than 7 each?
print(48/6<=7)
# Out:
# False

# %%
#Q20. Multiply 4 by 4. Is the result less than 20?
print(4*4<20)
# Out:
# True

# %%
#Q21. Add 13 and 7. Is the result divisible by 5?
result=13+7
print("the result divisible by 5 :",result%5==0)
# Out:
# the result divisible by 5 : True

# %%
#Q22. 20 apples are equally shared between 5 students. Does each get 4?
print("does each get 4:",20/5==4)
# Out:
# does each get 4: True

# %%
#Q23. Subtract 15 from 60. Is the result equal to 45?
print("Is the result equals to 45:",60-15==45)
# Out:
# Is the result equals to 45: True

# %%
#Q24. If you double 12, is the result more than 25?
print(12*2==25)
# Out:
# False

# %%
#Q25. Are 100 divided by 4 and 25 equal?
print(100/4==100/25)
# Out:
# False

# %%
#Q26. Add 5.5 and 4.5. Is the result 10?
print("Is the result:",5.5+4.5==10)
# Out:
# Is the result: True

# %%
#Q27. A number is 25. If you divide it by 4 using floor division, is the result 6?
print("Is the result 6:",25//4==6)
# Out:
# Is the result 6: True

# %%
#Q28. What is the remainder when 29 is divided by 5? Is it equal to 4?
result=29
print("Is it qual to 4:",result%5==4)
# Out:
# Is it qual to 4: True

# %%
#Q29. Is 3 ** 4 equal to 81?
print(3**4==81)
# Out:
# True

# %% [markdown]
# ##  2. COMPARISON OPERATORS with Mixed operators

# %%
#Q30. A bag contprintains 12 red balls and 8 blue balls. Is red > blue?
red=12
blue=8
print("Is red>blue:",red>blue)
# Out:
# Is red>blue: True

# %%
#Q31. Tom scored 89 in math and 76 in science. Did he score more than 160 in total?
print("Did he score more than 160 in total:",89+76>160)
# Out:
# Did he score more than 160 in total: True

# %%
#Q32. A store sells apples at $2.50 each. If you buy 4, is the total cost more than $10?
print("Is the total cost more than $10:", 2.50*4>10)
# Out:
# Is the total cost more than $10: False

# %%
#Q33. Alice has $100 and buys 3 books for $25 each. Will she have money left?
print("will she have money left:",100-3*25!=0)
# Out:
# will she have money left True

# %%
#Q34. A rectangle has length 10 and width 4. Is area greater than perimeter?
area=10*4
perimeter=2*(10+4)
print("Is area greater than perimeter?:",area>perimeter)
# Out:
# Is area greater than perimeter?: True

# %%
#Q35. Two friends have 45 and 55 marbles. Do they have equal marbles?
print("do they have equal marbles:",45==55)
# Out:
# do they have equal marbles: False

# %%
#Q36. A car travels 60 km/hr and a bike 40 km/hr. Is the car faster?
print("is the car faster:",60>40)
# Out:
# is the car faster: True

# %%
#Q37. Two numbers are 13 and 17. Is their sum an even number?
sum=13+17
print("Is their sum an even number:",sum%2==0)
# Out:
# Is their sum an even number: True

# %%
#Q38. A triangle has sides 3, 4, 5. Is it right-angled?
print("Is it right-angled:",3**2+4**2==5**2)
# Out:
# Is it right-angled: True

# %%
#Q39. Jenny had $50, bought items worth $35. Does she have less than $20 left?
print(" Does she have less than $20 left?:", 50-35<20)
# Out:
#  Does she have less than $20 left?: True

# %%
#Q40. A worker earns $80 per day. Is 6 days' earning more than $500?
print("is he earning more than $500:",80*6>500)
# Out:
# is he earning more than $500: False

# %%
#Q41. If a bottle contains 750 ml, do 4 bottles hold more than 3 liters?
print(" do 4 bottles hold more than 3 liters?:",750*4>3000)
# Out:
#  do 4 bottles hold more than 3 liters?: False

# %%
#Q42. Do two squares of side 4 and 5 have the same area?
print("Do two squares of side 4 and 5 have the same area?",4**2==5**2)
# Out:
# Do two squares of side 4 and 5 have the same area? False

# %%
#Q43. A triangle has angles 60, 60, 60. Do they sum to 180?
print("A triangle has angles 60, 60, 60. Do they sum to 180?:",60+60+60==180)
# Out:
# A triangle has angles 60, 60, 60. Do they sum to 180?: True

# %%
#Q44. If you split 100 into two equal parts, is one part greater than 60?
print("is one part greater than 60?:",100/2>60)
# Out:
# is one part greater than 60?: False

# %%
#Q45. Mike earned $400 in 8 days. Did he earn $50 daily?
print("Did he earn $50 daily?:",400/8==50)
# Out:
# Did he earn $50 daily?: True

# %%
#Q46. Compare 5 ** 2 and 25. Are they equal?
print(" Are they equal?:",5**2==25)
# Out:
#  Are they equal?: True

# %%
#Q47. Is (10 + 2) * 3 greater than 35?
print("greater than 35:",(10+2)*3>35)
# Out:
# greater than 35: True

# %%
#Q48. Do 8 and 8.0 compare equal?
print(8==8.0)
# Out:
# True

# %% [markdown]
# ##  3. LOGICAL OPERATORS

# %%
#Q49. Given a = 10 and b = 5, is (a > 5 and b < 10) True?
a=10
b=10
print(a>5 and b<10)
# Out:
# False

# %%
#Q50. If x = 8, is not (x > 10) True?
x=8
print(not(x>10))
# Out:
# True

# %%
#Q51. Is (5 < 3 or 7 == 7) True?
print(5<3 or 7==7)
# Out:
# True

# %% [markdown]
# ##  4. ASSIGNMENT OPERATORS

# %%
#Q52. If x = 10 and x += 5, is new x equal to 15?
x=10
x+=5
print("is new X equal to 15:",x==15)
# Out:
# is new X equal to 15: True

# %%
#Q53. If y = 20 and y -= 7, is the result less than 15?
y=20
y-=7
print(" is the result less than 15?:",y<15)
# Out:
#  is the result less than 15?: True

# %%
#Q54. Given x = 12 and x *= 2, is x equal to 24?
x=12
x*=2
print("Is x equal to 24?:",x==24)
# Out:
# Is x equal to 24?: True

# %% [markdown]
# ##  5. BITWISE OPERATORS

# %%
#Q55. If a = 6 and b = 3, is a & b equal to 2?
a=6
b=3
print("a & b equal to 2?:",a and b==2)
# Out:
# a & b equal to 2?: False

# %%
#Q56. If a = 6 and b = 3, is a | b equal to 7?
a=6
b=3
print(a|b==7)
# Out:
# True

# %%
#Q57. If a = 6 and b = 3, is a ^ b equal to 5?
print(a^b==5)
# Out:
# True

# %%
#Q58. If a = 4, is ~a equal to −5?
print(~a == -5)
# Out:
# False

# %%
#Q59. If a = 5, is a << 1 equal to 10?
a=5

print(a<<1==10)
# Out:
# True

# %%
#Q60. If a = 8, is a >> 2 equal to 2?
a=8
print(a>>2==2)
# Out:
# True
