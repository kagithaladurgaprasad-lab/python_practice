# %%
#1.  Scenario: Odd or Even Duel
#Create a program that takes two numbers as input.
# Add them and determine the winner:
#If the sum is even, Player 1 wins
#If the sum is odd, Player 2 wins
a=int(input("enter the number"))
b=int(input("enter the second number"))
sumofab=a+b
if sumofab%2==0:
    print("Player 1 wins")
else:
    print("Player 2 wins")
# Out:
# enter the number 12
# enter the second number 34
# Player 1 wins

# %%
#2.  Scenario: Color Mixer
#Create a program that accepts two primary colors: "red", "blue", "yellow".
 #Return the secondary color formed by mixing them:
#red + blue → purple
#red + yellow → orange
#blue + yellow → green
#If both colors are the same or invalid combination, output "Invalid".
a=input("Enter the first primary color from 'red','blue','yellow'")
b=input("Enter the secondary primary color from 'red','blue','yellow'")
if a=="red"or"blue" and b=="blue" or "red":
    print("purple")
elif a=="red"or"yellow" and b=="yellow "or "red":
    print("orange")
elif a=="blue"or "yellow" and b=="yellow" or "blue":
    print("green")
else:
    print("Invalid")
# Out:
# Enter the first primary color from 'red','blue','yellow' blue
# Enter the secondary primary color from 'red','blue','yellow' blue
# purple

# %%
#3.  Scenario: Dice Roll Battle
#Create a program that simulates a dice game between two players.
 #Each player rolls a number (1–6).
#The higher number wins
#If same → it's a draw

a=input("enter the first number between 1 to 6")
b=input("enter the second number")
if a>b:
    print("first number is higher")
elif a<b:
    print("second number is higher")
else:
    print("it's a draw")
# Out:
# enter the first number between 1 to 6 1
# enter the second number 3
# second number is higher

# %%
#4.  Scenario: Vowel Checker
#Write a program that takes a single character.
 #Check if it’s a vowel (a, e, i, o, u).
 #Test Cases:
 #Input: a ➞ Output: Vowel
 #Input: b ➞ Output: Consonant
 #Input: e ➞ Output: Vowel
 #Input: z ➞ Output: Consonant
a=input("enter the character")
values="aeiou"
if a in values:
    print("vowel")
else:
    print("Consonant")
# Out:
# enter the character e
# vowel

# %%
#5.  Scenario: Age Category Detector
#Create a program that takes an age and classifies it:
#<13 → Kid
#13–19 → Teen
#20–59 → Adult
#60+ → Senior
a=int(input("enter the age"))
if a<13:
    print("kid")
elif a<19:
    print("Teen")
elif a<59:
    print("Adult")
else:
    print("Senior")
# Out:
# enter the age 12
# kid

# %%
## 6.  Scenario: Leap Year Checker
#Write a program that checks if a year is a leap year.
 #A leap year is divisible by 4, but if divisible by 100, must also be divisible by 400.
a=int(input("enter the year"))
if a%4==0:
    if a%100==0:
        if a%400==0:
            print("leap year")
        else:
            print("not leap year")
    else:
        print("leap year")
           
else:
    print("not a leap year")
# Out:
# enter the year 1900

# %%
#7.  Scenario: Word Length Game
#Create a program that accepts two words.
#Print the word with more characters.
#If both have the same length, print "Same length".
a=input("enter the  first word")
b=input("enter the second word")
if len(a)>len(b):
    print("first word has more characters")
elif len(a)<len(b):
    print("second word has more characters")
else:
    print("same length")
# Out:
# enter the  first word rrrff
# enter the second word gtgfefedf
# second word has more characters

# %%
#38.  Scenario: Number Type Identifier
#Create a program that takes a number and prints:
#"Positive" if number > 0
#"Negative" if number < 0
#"Zero" if number == 0
a=int(input("enter the number:"))
if a>0:
    print("Positive")
elif a<0:
    print("negative")
else:
    print("zero")
# Out:
# enter the number: 0
# zero

# %%
#9.  Scenario: Traffic Signal Checker
#Create a program that takes a signal color and an action.
 #Check if the action is valid:
#red ➞ stop
#green ➞ go
#yellow ➞ wait
a=input("enter the color:")
b=input("enter an action:")
if a=="red" and b=="stop":
    print("valid")
elif a=="green" and b=="go":
    print("valid")
elif a=="yellow" and b=="wait":
    print("valid")
else:
    print("invalid")
# Out:
# enter the color: red
# enter an action: stop
# valid

# %%
#10.  Scenario: Fruit Category
#Write a program that takes a fruit name and returns its category:
#Citrus: orange, lemon
#Berry: strawberry, blueberry
#Tropical: mango, pineapple
a=input("enter the fruit name:")
if a=="lemon":
    print("citrus")
elif a=="straberry" or"blueberry":
    print("berry")
elif a=="mango"or "pineapple":
    print("tropical")
else:
    print("unknown")
# Out:
# enter the fruit name: lemon
# citrus

# %%
#11.  Scenario: Grade Evaluator
#Create a program that takes marks (0–100) and prints grade:
#<40: Fail
#40–59: Pass
#60–79: Good
#80–100: Excellent
a=int(input("enter the marks:"))
if a<40:
    print("Fail")
elif a<=59:
    print("pass")
elif a<=79:
    print("good")
if a<=100:
    print("excllent")
else:
    print("limit exceeded")
# Out:
# enter the marks: 123
# limit exceeded

# %%
#12.  Scenario: Lucky 7 Game
#Write a program that takes a number.
 #If it’s divisible by 7, print "Lucky", else "Try Again".
 #Test Cases:
# Input: 14 ➞ Output: Lucky
 #Input: 9 ➞ Output: Try Again
 #Input: 21 ➞ Output: Lucky
 #Input: 22 ➞ Output: Try Again
a=int(input("enter a number"))
if a%7==0:
    print("Lucky")
else:
    print("Try again")
# Out:
# enter a number 35
# Lucky

# %%
#13.  Scenario: Even or Odd
#Create a program that checks if a number is even or odd.
a=int(input("enter the number:"))
if a%2==0:
    print("even")
else:
    print("odd")
# Out:
# enter the number: 22
# even

# %%
#14.  Scenario: Multiplication or Division
#Take three inputs: operation ("multiply" or "divide") and two numbers.
 #Perform the operation.
op=input("select the operation 'MULTIPLY' OR 'DIVIDE':")
a=int(input("enter the number"))
b=int(input("enter the second number"))
if op=="multiply":
    print(a*b)
elif b==0 and op=="divide":
    print("cannot divide with zer0")
elif op=="divide":
    print(a/b)
# Out:
# select the operation 'MULTIPLY' OR 'DIVIDE': multiply
# enter the number 12
# enter the second number 4
# 48

# %%
#15.  Scenario: Simple Calculator
#Take two numbers and an operator (+, -, *, /)
 #Perform the operation and print the result.
a=int(input("enter the number:"))
b=int(input("enter the second number:"))
op=input("select one operator: + - / *:")
if op=="+":
    print(a+b)
elif op=="-":
    print(a-b)
elif op=="/":
    print(a/b)
elif op=="*":
    print(a*b)
# Out:
# enter the number: 12
# enter the second number: 34
# select one operator: + - / *: /
# 0.35294117647058826

# %%
#16.  Scenario: Max of Three
#Take three numbers and print the maximum.
a=int(input("enter the number:"))
b=int(input("enter the second number:"))
c=int(input("enter the third number:"))
print(max(a,b,c))
# Out:
# enter the number: 1
# enter the second number: 2
# enter the third number: 4
# 4

# %%
#17.  Scenario: Letter Case Checker
#Input a single character.
#Check if it’s uppercase, lowercase, or not an alphabet.
a=input("enter a character:")
if a.isupper() and a.isalpha():
    print("upper case")
elif a.islower() and a.isalpha():
    print("lower case")
else:
    print("not a letter")
# Out:
# enter a character: 1
# not a letter

# %%
#8.  Scenario: Guess the Word
#Create a program that compares a guessed word to a hidden word.
 #If it matches → "Correct"
 #Else → "Try Again"
hidden="python"
a=input("enter the guess word:")
if a==hidden:
    print("Correct")
else:
    print("Try Again")
# Out:
# enter the guess word: rtee
# Try Again

# %%
#19.  Scenario: Triangle Type Checker
#Input three sides of a triangle.
 #Print the type:
#All equal ➞ Equilateral
#Two equal ➞ Isosceles
#All different ➞ Scalene
a=int(input("enter the side a"))
b=int(input("enter the side b"))
c=int(input("enter the side c"))
if a==b==c:
    print("Equilateral")
elif a==b or b==c or a==c or b==a:
    print("Isosceles")
elif a!=b and b!=c and c!=a:
    print(Scalene)
# Out:
# enter the side a 1
# enter the side b 2
# enter the side c 3
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[68], line 15
#      13     print("Isosceles")
#      14 elif a!=b and b!=c and c!=a:
# ---> 15     print(Scalene)
#
# NameError: name 'Scalene' is not defined
